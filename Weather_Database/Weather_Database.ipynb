# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from config import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-90.000, high=90.000, size=1500)
coordinates = zip(lats, lngs)
coordinates

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 598

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url = url + "&q=" + city.replace(" ","+")
city_weather = req.get(city_url).json()

# %%
import json

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1

set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)


    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    
    record_count += 1
    
    #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = req.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Country": city_country,
                        
                          "Current Description": city_description})

        
# If an error is experienced, skip the city.
    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sao marcos
# Processing Record 2 of Set 1 | oxapampa
# Processing Record 3 of Set 1 | chlorakas
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | clyde river
# Processing Record 7 of Set 1 | la palma
# Processing Record 8 of Set 1 | marondera
# Processing Record 9 of Set 1 | cayenne
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | turukhansk
# Processing Record 15 of Set 1 | jizan
# Processing Record 16 of Set 1 | virginia beach
# Processing Record 17 of Set 1 | ancud
# Processing Record 18 of Set 1 | qaqortoq
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | kemijarvi
# Processing Record 21 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 22 of Set 1 | hatillo
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 1 | olafsvik
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | bajina basta
# Processing Record 31 of Set 1 | korla
# Processing Record 32 of Set 1 | tasiilaq
# Processing Record 33 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | hualmay
# Processing Record 36 of Set 1 | nizwa
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | quatre cocos
# Processing Record 39 of Set 1 | paita
# Processing Record 40 of Set 1 | kvarkeno
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | buturlino
# Processing Record 46 of Set 1 | leme
# Processing Record 47 of Set 1 | havelock
# Processing Record 48 of Set 1 | bubaque
# Processing Record 49 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 1 | swakopmund
# Processing Record 1 of Set 2 | port alfred
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | gat
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | envira
# Processing Record 6 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 2 | jalu
# Processing Record 8 of Set 2 | sao filipe
# Processing Record 9 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 10 of Set 2 | plouzane
# Processing Record 11 of Set 2 | kutum
# Processing Record 12 of Set 2 | gamba
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | segarcea vale
# Processing Record 15 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 16 of Set 2 | mola di bari
# Processing Record 17 of Set 2 | burica
# City not found. Skipping...
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | parabel
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | skegness
# Processing Record 22 of Set 2 | qaanaaq
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | campo verde
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | santa lucia
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | zaozerne
# Processing Record 30 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 31 of Set 2 | ayios matthaios
# City not found. Skipping...
# Processing Record 32 of Set 2 | caravelas
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | marrakesh
# Processing Record 35 of Set 2 | key west
# Processing Record 36 of Set 2 | hobyo
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | bathsheba
# Processing Record 39 of Set 2 | progreso
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | saint george
# Processing Record 42 of Set 2 | marawi
# Processing Record 43 of Set 2 | asosa
# Processing Record 44 of Set 2 | nouakchott
# Processing Record 45 of Set 2 | khorixas
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | charlestown
# Processing Record 48 of Set 2 | muros
# Processing Record 49 of Set 2 | boende
# Processing Record 50 of Set 2 | santiago del estero
# Processing Record 1 of Set 3 | sao sebastiao
# Processing Record 2 of Set 3 | margate
# Processing Record 3 of Set 3 | berlevag
# Processing Record 4 of Set 3 | harper
# Processing Record 5 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 3 | havoysund
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | tutoia
# Processing Record 9 of Set 3 | pucallpa
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | tonj
# Processing Record 12 of Set 3 | mitsamiouli
# Processing Record 13 of Set 3 | plettenberg bay
# Processing Record 14 of Set 3 | sao felix do xingu
# Processing Record 15 of Set 3 | viransehir
# Processing Record 16 of Set 3 | geraldton
# Processing Record 17 of Set 3 | zvishavane
# Processing Record 18 of Set 3 | richards bay
# Processing Record 19 of Set 3 | cheremukhovo
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | aripuana
# Processing Record 22 of Set 3 | tlmace
# Processing Record 23 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | gidole
# Processing Record 26 of Set 3 | oriximina
# Processing Record 27 of Set 3 | ensley
# Processing Record 28 of Set 3 | ratnapura
# Processing Record 29 of Set 3 | ornskoldsvik
# Processing Record 30 of Set 3 | san felipe
# Processing Record 31 of Set 3 | mogadishu
# Processing Record 32 of Set 3 | semey
# Processing Record 33 of Set 3 | viedma
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | rafaela
# Processing Record 36 of Set 3 | trollhattan
# Processing Record 37 of Set 3 | sosua
# Processing Record 38 of Set 3 | coihaique
# Processing Record 39 of Set 3 | la asuncion
# Processing Record 40 of Set 3 | amapa
# Processing Record 41 of Set 3 | miraflores
# Processing Record 42 of Set 3 | garoua
# Processing Record 43 of Set 3 | at-bashi
# Processing Record 44 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 3 | ostrovnoy
# Processing Record 46 of Set 3 | porbandar
# Processing Record 47 of Set 3 | gewane
# Processing Record 48 of Set 3 | riyadh
# Processing Record 49 of Set 3 | krasnoselkup
# Processing Record 50 of Set 3 | ngorongoro
# Processing Record 1 of Set 4 | nizhniy odes
# Processing Record 2 of Set 4 | staryy krym
# Processing Record 3 of Set 4 | nioro
# Processing Record 4 of Set 4 | arona
# Processing Record 5 of Set 4 | kavaratti
# Processing Record 6 of Set 4 | hambantota
# Processing Record 7 of Set 4 | cuenca
# Processing Record 8 of Set 4 | mpulungu
# Processing Record 9 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | shakawe
# Processing Record 11 of Set 4 | taoudenni
# Processing Record 12 of Set 4 | kovur
# Processing Record 13 of Set 4 | sergeyevka
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | salalah
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | mindelo
# Processing Record 18 of Set 4 | mecca
# Processing Record 19 of Set 4 | ambositra
# Processing Record 20 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 4 | alcanena
# Processing Record 22 of Set 4 | seminole
# Processing Record 23 of Set 4 | husavik
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | vallenar
# Processing Record 26 of Set 4 | xuddur
# Processing Record 27 of Set 4 | pocone
# Processing Record 28 of Set 4 | beinamar
# Processing Record 29 of Set 4 | pangody
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | sabha
# Processing Record 32 of Set 4 | kolchugino
# Processing Record 33 of Set 4 | heiligenhafen
# Processing Record 34 of Set 4 | panaba
# Processing Record 35 of Set 4 | morondava
# Processing Record 36 of Set 4 | ardesen
# Processing Record 37 of Set 4 | benjamin aceval
# Processing Record 38 of Set 4 | grand baie
# Processing Record 39 of Set 4 | nuuk
# Processing Record 40 of Set 4 | moose factory
# Processing Record 41 of Set 4 | maroua
# Processing Record 42 of Set 4 | prado
# Processing Record 43 of Set 4 | hamilton
# Processing Record 44 of Set 4 | jardim
# Processing Record 45 of Set 4 | thompson
# Processing Record 46 of Set 4 | victoria
# Processing Record 47 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 4 | weligama
# Processing Record 49 of Set 4 | kabelvag
# Processing Record 50 of Set 4 | umm kaddadah
# Processing Record 1 of Set 5 | saint-joseph
# Processing Record 2 of Set 5 | diamantino
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | acarau
# Processing Record 5 of Set 5 | talnakh
# Processing Record 6 of Set 5 | kudahuvadhoo
# Processing Record 7 of Set 5 | ambilobe
# Processing Record 8 of Set 5 | phalia
# Processing Record 9 of Set 5 | boa vista
# Processing Record 10 of Set 5 | faya
# Processing Record 11 of Set 5 | lamu
# Processing Record 12 of Set 5 | rajsamand
# Processing Record 13 of Set 5 | matagami
# Processing Record 14 of Set 5 | joensuu
# Processing Record 15 of Set 5 | goderich
# Processing Record 16 of Set 5 | inhambane
# Processing Record 17 of Set 5 | zaraza
# Processing Record 18 of Set 5 | matara
# Processing Record 19 of Set 5 | crateus
# Processing Record 20 of Set 5 | zlobin
# Processing Record 21 of Set 5 | san cristobal
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | lixourion
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | brigantine
# Processing Record 26 of Set 5 | anori
# Processing Record 27 of Set 5 | tazmalt
# Processing Record 28 of Set 5 | hearst
# Processing Record 29 of Set 5 | nkhotakota
# Processing Record 30 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 5 | siavonga
# Processing Record 32 of Set 5 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 33 of Set 5 | black river
# Processing Record 34 of Set 5 | taltal
# Processing Record 35 of Set 5 | wattegama
# Processing Record 36 of Set 5 | mar del plata
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | ellisras
# Processing Record 39 of Set 5 | minturno
# Processing Record 40 of Set 5 | walvis bay
# Processing Record 41 of Set 5 | fortaleza
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | kilindoni
# Processing Record 44 of Set 5 | nefteyugansk
# Processing Record 45 of Set 5 | codrington
# Processing Record 46 of Set 5 | warri
# Processing Record 47 of Set 5 | mumford
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | codajas
# Processing Record 50 of Set 5 | chokwe
# Processing Record 1 of Set 6 | umba
# Processing Record 2 of Set 6 | chimbote
# Processing Record 3 of Set 6 | vryburg
# Processing Record 4 of Set 6 | haverfordwest
# Processing Record 5 of Set 6 | sorland
# Processing Record 6 of Set 6 | hofn
# Processing Record 7 of Set 6 | berdsk
# Processing Record 8 of Set 6 | antalaha
# Processing Record 9 of Set 6 | kamina
# Processing Record 10 of Set 6 | qasigiannguit
# Processing Record 11 of Set 6 | marsa matruh
# Processing Record 12 of Set 6 | littlehampton
# Processing Record 13 of Set 6 | penicuik
# Processing Record 14 of Set 6 | dover
# Processing Record 15 of Set 6 | atlantis
# Processing Record 16 of Set 6 | sinfra
# Processing Record 17 of Set 6 | dullewala
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | brownsburg
# Processing Record 20 of Set 6 | fosforitnyy
# Processing Record 21 of Set 6 | malatya
# Processing Record 22 of Set 6 | beloha
# Processing Record 23 of Set 6 | llata
# Processing Record 24 of Set 6 | vardo
# Processing Record 25 of Set 6 | necochea
# Processing Record 26 of Set 6 | oranjestad
# Processing Record 27 of Set 6 | itaqui
# Processing Record 28 of Set 6 | rincon
# Processing Record 29 of Set 6 | liverpool
# Processing Record 30 of Set 6 | lavumisa
# Processing Record 31 of Set 6 | brignais
# Processing Record 32 of Set 6 | ust-shonosha
# Processing Record 33 of Set 6 | pizarro
# Processing Record 34 of Set 6 | huarmey
# Processing Record 35 of Set 6 | dunmore east
# Processing Record 36 of Set 6 | imbituba
# Processing Record 37 of Set 6 | oranjemund
# Processing Record 38 of Set 6 | cerquilho
# Processing Record 39 of Set 6 | nalut
# Processing Record 40 of Set 6 | rocha
# Processing Record 41 of Set 6 | trairi
# Processing Record 42 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 6 | mafinga
# Processing Record 44 of Set 6 | vila velha
# Processing Record 45 of Set 6 | kaspiyskiy
# Processing Record 46 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 6 | bonavista
# Processing Record 48 of Set 6 | andenes
# Processing Record 49 of Set 6 | nadym
# Processing Record 50 of Set 6 | santa rosa
# Processing Record 1 of Set 7 | veraval
# Processing Record 2 of Set 7 | mao
# Processing Record 3 of Set 7 | klaksvik
# Processing Record 4 of Set 7 | teguldet
# Processing Record 5 of Set 7 | redhakhol
# City not found. Skipping...
# Processing Record 6 of Set 7 | the valley
# Processing Record 7 of Set 7 | praia
# Processing Record 8 of Set 7 | marystown
# Processing Record 9 of Set 7 | iqaluit
# Processing Record 10 of Set 7 | saint-paul
# Processing Record 11 of Set 7 | igarka
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | bandarbeyla
# Processing Record 14 of Set 7 | guarda
# Processing Record 15 of Set 7 | kribi
# Processing Record 16 of Set 7 | mezen
# Processing Record 17 of Set 7 | foumbot
# Processing Record 18 of Set 7 | beira
# Processing Record 19 of Set 7 | baherden
# Processing Record 20 of Set 7 | leh
# Processing Record 21 of Set 7 | kangundo
# Processing Record 22 of Set 7 | anklesvar
# City not found. Skipping...
# Processing Record 23 of Set 7 | tukrah
# Processing Record 24 of Set 7 | ponta delgada
# Processing Record 25 of Set 7 | wolow
# Processing Record 26 of Set 7 | eyl
# Processing Record 27 of Set 7 | conde
# Processing Record 28 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 7 | miranda
# Processing Record 30 of Set 7 | malanje
# Processing Record 31 of Set 7 | yarim
# Processing Record 32 of Set 7 | camacha
# Processing Record 33 of Set 7 | piacabucu
# Processing Record 34 of Set 7 | kuvandyk
# Processing Record 35 of Set 7 | natal
# Processing Record 36 of Set 7 | jamame
# Processing Record 37 of Set 7 | aswan
# Processing Record 38 of Set 7 | gori
# Processing Record 39 of Set 7 | botwood
# Processing Record 40 of Set 7 | praia da vitoria
# Processing Record 41 of Set 7 | kuryk
# Processing Record 42 of Set 7 | police
# Processing Record 43 of Set 7 | itapirapua
# Processing Record 44 of Set 7 | meridian
# Processing Record 45 of Set 7 | machhlishahr
# Processing Record 46 of Set 7 | pedasi
# Processing Record 47 of Set 7 | kuvshinovo
# Processing Record 48 of Set 7 | hadgaon
# Processing Record 49 of Set 7 | carora
# Processing Record 50 of Set 7 | boa esperanca
# Processing Record 1 of Set 8 | cockburn town
# Processing Record 2 of Set 8 | jhang
# Processing Record 3 of Set 8 | gorom-gorom
# Processing Record 4 of Set 8 | uusikaupunki
# Processing Record 5 of Set 8 | delaware
# Processing Record 6 of Set 8 | alta
# Processing Record 7 of Set 8 | penzance
# Processing Record 8 of Set 8 | bengkulu
# Processing Record 9 of Set 8 | yar-sale
# Processing Record 10 of Set 8 | elbistan
# Processing Record 11 of Set 8 | brae
# Processing Record 12 of Set 8 | zdzieszowice
# Processing Record 13 of Set 8 | aleksandrovka
# Processing Record 14 of Set 8 | san andres
# Processing Record 15 of Set 8 | pavlodar
# Processing Record 16 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 17 of Set 8 | adrar
# Processing Record 18 of Set 8 | meulaboh
# Processing Record 19 of Set 8 | neuquen
# Processing Record 20 of Set 8 | mandali
# Processing Record 21 of Set 8 | constantine
# Processing Record 22 of Set 8 | vuktyl
# Processing Record 23 of Set 8 | kachiry
# Processing Record 24 of Set 8 | arroyo
# Processing Record 25 of Set 8 | ponta do sol
# Processing Record 26 of Set 8 | januaria
# Processing Record 27 of Set 8 | henties bay
# Processing Record 28 of Set 8 | kanniyakumari
# Processing Record 29 of Set 8 | yuzhne
# Processing Record 30 of Set 8 | marabba
# Processing Record 31 of Set 8 | teguise
# Processing Record 32 of Set 8 | defiance
# Processing Record 33 of Set 8 | altamira
# Processing Record 34 of Set 8 | pertuis
# Processing Record 35 of Set 8 | longyearbyen
# Processing Record 36 of Set 8 | oistins
# Processing Record 37 of Set 8 | rio gallegos
# Processing Record 38 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 8 | himora
# City not found. Skipping...
# Processing Record 40 of Set 8 | sur
# Processing Record 41 of Set 8 | tirlyanskiy
# Processing Record 42 of Set 8 | rehoboth
# Processing Record 43 of Set 8 | hit
# Processing Record 44 of Set 8 | zhob
# Processing Record 45 of Set 8 | jurado
# Processing Record 46 of Set 8 | tammisaari
# Processing Record 47 of Set 8 | balkanabat
# Processing Record 48 of Set 8 | saint-francois
# Processing Record 49 of Set 8 | wezembeek-oppem
# Processing Record 50 of Set 8 | belyy yar
# Processing Record 1 of Set 9 | sechura
# Processing Record 2 of Set 9 | molchanovo
# Processing Record 3 of Set 9 | saint-augustin
# Processing Record 4 of Set 9 | guane
# Processing Record 5 of Set 9 | banda aceh
# Processing Record 6 of Set 9 | garango
# Processing Record 7 of Set 9 | hurghada
# Processing Record 8 of Set 9 | aguadilla
# Processing Record 9 of Set 9 | kolyvan
# Processing Record 10 of Set 9 | arenzano
# Processing Record 11 of Set 9 | villazon
# Processing Record 12 of Set 9 | ichnya
# Processing Record 13 of Set 9 | oudtshoorn
# Processing Record 14 of Set 9 | pangnirtung
# Processing Record 15 of Set 9 | villefranche-de-rouergue
# Processing Record 16 of Set 9 | tabou
# Processing Record 17 of Set 9 | mayahi
# Processing Record 18 of Set 9 | san luis
# Processing Record 19 of Set 9 | matay
# Processing Record 20 of Set 9 | emba
# Processing Record 21 of Set 9 | volgodonsk
# Processing Record 22 of Set 9 | murree
# Processing Record 23 of Set 9 | kochki
# Processing Record 24 of Set 9 | kapoeta
# Processing Record 25 of Set 9 | macamic
# Processing Record 26 of Set 9 | waw
# Processing Record 27 of Set 9 | ust-kan
# Processing Record 28 of Set 9 | moyo
# Processing Record 29 of Set 9 | humaita
# Processing Record 30 of Set 9 | cap malheureux
# Processing Record 31 of Set 9 | muzaffarabad
# Processing Record 32 of Set 9 | zapresic
# Processing Record 33 of Set 9 | port blair
# Processing Record 34 of Set 9 | shieli
# Processing Record 35 of Set 9 | belmonte
# Processing Record 36 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 9 | mirwah
# Processing Record 38 of Set 9 | ankazoabo
# Processing Record 39 of Set 9 | dakar
# Processing Record 40 of Set 9 | sao francisco
# Processing Record 41 of Set 9 | tiznit
# Processing Record 42 of Set 9 | abu dhabi
# Processing Record 43 of Set 9 | chicama
# Processing Record 44 of Set 9 | rosaryville
# Processing Record 45 of Set 9 | itacoatiara
# Processing Record 46 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 9 | uaua
# Processing Record 48 of Set 9 | anand
# Processing Record 49 of Set 9 | paamiut
# Processing Record 50 of Set 9 | marfino
# Processing Record 1 of Set 10 | roura
# Processing Record 2 of Set 10 | skibbereen
# Processing Record 3 of Set 10 | bukan
# Processing Record 4 of Set 10 | kingsport
# Processing Record 5 of Set 10 | rio grande
# Processing Record 6 of Set 10 | springbok
# Processing Record 7 of Set 10 | valparaiso
# Processing Record 8 of Set 10 | talbahat
# Processing Record 9 of Set 10 | yamoussoukro
# Processing Record 10 of Set 10 | abensberg
# Processing Record 11 of Set 10 | iracoubo
# Processing Record 12 of Set 10 | sturovo
# Processing Record 13 of Set 10 | maceio
# Processing Record 14 of Set 10 | aykino
# Processing Record 15 of Set 10 | ormara
# Processing Record 16 of Set 10 | saint-leu
# Processing Record 17 of Set 10 | boundiali
# Processing Record 18 of Set 10 | banepa
# Processing Record 19 of Set 10 | kouroussa
# Processing Record 20 of Set 10 | nema
# Processing Record 21 of Set 10 | staritsa
# Processing Record 22 of Set 10 | taburbah
# City not found. Skipping...
# Processing Record 23 of Set 10 | meaford
# Processing Record 24 of Set 10 | thunder bay
# Processing Record 25 of Set 10 | lubango
# Processing Record 26 of Set 10 | el alto
# Processing Record 27 of Set 10 | mehamn
# Processing Record 28 of Set 10 | bouca
# Processing Record 29 of Set 10 | san onofre
# Processing Record 30 of Set 10 | plasencia
# Processing Record 31 of Set 10 | biu
# Processing Record 32 of Set 10 | riohacha
# Processing Record 33 of Set 10 | beroroha
# Processing Record 34 of Set 10 | bundi
# Processing Record 35 of Set 10 | andilamena
# Processing Record 36 of Set 10 | tapes
# Processing Record 37 of Set 10 | charsadda
# Processing Record 38 of Set 10 | esil
# Processing Record 39 of Set 10 | ceres
# Processing Record 40 of Set 10 | dharchula
# Processing Record 41 of Set 10 | illapel
# Processing Record 42 of Set 10 | tsabong
# Processing Record 43 of Set 10 | kamenka
# Processing Record 44 of Set 10 | williamsburg
# Processing Record 45 of Set 10 | saint-pierre
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | malakal
# Processing Record 48 of Set 10 | barao de melgaco
# Processing Record 49 of Set 10 | copenhagen
# Processing Record 50 of Set 10 | visby
# Processing Record 1 of Set 11 | araguaina
# Processing Record 2 of Set 11 | umea
# Processing Record 3 of Set 11 | bahadurganj
# Processing Record 4 of Set 11 | mahon
# Processing Record 5 of Set 11 | carutapera
# Processing Record 6 of Set 11 | barcelos
# Processing Record 7 of Set 11 | requena
# Processing Record 8 of Set 11 | agirish
# Processing Record 9 of Set 11 | santarem
# Processing Record 10 of Set 11 | porto nacional
# Processing Record 11 of Set 11 | uyutne
# Processing Record 12 of Set 11 | astana
# Processing Record 13 of Set 11 | buchanan
# Processing Record 14 of Set 11 | bahia honda
# Processing Record 15 of Set 11 | ust-koksa
# Processing Record 16 of Set 11 | biltine
# Processing Record 17 of Set 11 | carnarvon
# Processing Record 18 of Set 11 | cascais
# Processing Record 19 of Set 11 | kuusamo
# Processing Record 20 of Set 11 | valdosta
# Processing Record 21 of Set 11 | sept-iles
# Processing Record 22 of Set 11 | benghazi
# Processing Record 23 of Set 11 | ilhabela
# Processing Record 24 of Set 11 | uvinza
# Processing Record 25 of Set 11 | belfast
# Processing Record 26 of Set 11 | junin
# Processing Record 27 of Set 11 | ordu
# Processing Record 28 of Set 11 | kedrovyy
# Processing Record 29 of Set 11 | port-cartier
# Processing Record 30 of Set 11 | paragominas
# Processing Record 31 of Set 11 | berbera
# Processing Record 32 of Set 11 | estelle
# Processing Record 33 of Set 11 | peshkopi
# Processing Record 34 of Set 11 | suda
# Processing Record 35 of Set 11 | demba
# Processing Record 36 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 11 | aller
# Processing Record 38 of Set 11 | salym
# Processing Record 39 of Set 11 | spanish town
# Processing Record 40 of Set 11 | masuguru
# Processing Record 41 of Set 11 | sioux lookout
# Processing Record 42 of Set 11 | jucurutu
# Processing Record 43 of Set 11 | amasya
# Processing Record 44 of Set 11 | orcopampa
# Processing Record 45 of Set 11 | vangaindrano
# Processing Record 46 of Set 11 | cape canaveral
# Processing Record 47 of Set 11 | menongue
# Processing Record 48 of Set 11 | shetpe
# Processing Record 49 of Set 11 | rawson
# Processing Record 50 of Set 11 | nikolayevskaya
# Processing Record 1 of Set 12 | kalabo
# Processing Record 2 of Set 12 | strezhevoy
# Processing Record 3 of Set 12 | vasai
# Processing Record 4 of Set 12 | perevoz
# Processing Record 5 of Set 12 | xai-xai
# Processing Record 6 of Set 12 | aranda de duero
# Processing Record 7 of Set 12 | zambezi
# Processing Record 8 of Set 12 | pozo colorado
# Processing Record 9 of Set 12 | tikapur
# Processing Record 10 of Set 12 | trussville
# Processing Record 11 of Set 12 | exeter
# Processing Record 12 of Set 12 | anloga
# Processing Record 13 of Set 12 | porto novo
# Processing Record 14 of Set 12 | lazurne
# Processing Record 15 of Set 12 | puerto leguizamo
# Processing Record 16 of Set 12 | general roca
# Processing Record 17 of Set 12 | maniitsoq
# Processing Record 18 of Set 12 | bayan
# Processing Record 19 of Set 12 | opuwo
# Processing Record 20 of Set 12 | roald
# Processing Record 21 of Set 12 | road town
# Processing Record 22 of Set 12 | sikonge
# Processing Record 23 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 24 of Set 12 | paraiso
# Processing Record 25 of Set 12 | urengoy
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | quelimane
# Processing Record 28 of Set 12 | ginir
# Processing Record 29 of Set 12 | antofagasta
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | palma di montechiaro
# Processing Record 32 of Set 12 | ugoofaaru
# Processing Record 33 of Set 12 | kashira
# Processing Record 34 of Set 12 | conceicao da barra
# Processing Record 35 of Set 12 | casablanca
# Processing Record 36 of Set 12 | sambava
# Processing Record 37 of Set 12 | tromso
# Processing Record 38 of Set 12 | albertville
# Processing Record 39 of Set 12 | kharp
# Processing Record 40 of Set 12 | issoire
# Processing Record 41 of Set 12 | dunda
# Processing Record 42 of Set 12 | tucuman
# Processing Record 43 of Set 12 | owando
# Processing Record 44 of Set 12 | niono
# Processing Record 45 of Set 12 | czestochowa
# Processing Record 46 of Set 12 | kizema
# Processing Record 47 of Set 12 | kaoma
# Processing Record 48 of Set 12 | pachino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Sao Marcos -28.9711  -51.0681     66.72        98          32        3.94
# 1     Oxapampa -10.5775  -75.4017     59.67        98          97        2.55
# 2    Chlorakas  34.8042   32.4083     54.48        67          82        9.22
# 3    Grindavik  63.8424  -22.4338     41.47        93          75        3.44
# 4  Clyde River  70.4692  -68.5914     -1.97        84          40       10.36
# 5     La Palma  33.8464 -118.0467     83.97        55          20        8.05
# 6    Marondera -18.1853   31.5519     55.76        94          93        9.64
# 7      Cayenne   4.9333  -52.3333     82.09         1          40        2.30
# 8    Cape Town -33.9258   18.4232     59.92        74           0       10.00
# 9   Bredasdorp -34.5322   20.0403     53.24        83           0        3.44
#
#   Country                 Date Current Description
# 0      BR  2022-04-27 01:08:38    scattered clouds
# 1      PE  2022-04-27 01:08:43     overcast clouds
# 2      CY  2022-04-27 01:08:43       broken clouds
# 3      IS  2022-04-27 01:00:10       broken clouds
# 4      CA  2022-04-27 01:08:44          light snow
# 5      US  2022-04-27 01:08:44          few clouds
# 6      ZW  2022-04-27 01:08:45     overcast clouds
# 7      GF  2022-04-27 01:08:45    scattered clouds
# 8      ZA  2022-04-27 01:06:11           clear sky
# 9      ZA  2022-04-27 01:08:46           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Marcos      BR -28.9711  -51.0681     66.72        98          32
# 1     Oxapampa      PE -10.5775  -75.4017     59.67        98          97
# 2    Chlorakas      CY  34.8042   32.4083     54.48        67          82
# 3    Grindavik      IS  63.8424  -22.4338     41.47        93          75
# 4  Clyde River      CA  70.4692  -68.5914     -1.97        84          40
# 5     La Palma      US  33.8464 -118.0467     83.97        55          20
# 6    Marondera      ZW -18.1853   31.5519     55.76        94          93
# 7      Cayenne      GF   4.9333  -52.3333     82.09         1          40
# 8    Cape Town      ZA -33.9258   18.4232     59.92        74           0
# 9   Bredasdorp      ZA -34.5322   20.0403     53.24        83           0
#
#    Wind Speed Current Description
# 0        3.94    scattered clouds
# 1        2.55     overcast clouds
# 2        9.22       broken clouds
# 3        3.44       broken clouds
# 4       10.36          light snow
# 5        8.05          few clouds
# 6        9.64     overcast clouds
# 7        2.30    scattered clouds
# 8       10.00           clear sky
# 9        3.44           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
